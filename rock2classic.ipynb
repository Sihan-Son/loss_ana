# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('rock2classic')
path = os.getcwd()
# Out:
# 'D:\\Project\\ML\\loss_analytics\\rock2classic'

# %%
g_ = np.array(pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None))
a2b_ = np.array(pd.read_csv(os.path.join(path, 'a2b.csv'), header=None))
b2a_ = np.array(pd.read_csv(os.path.join(path, 'b2a.csv'), header=None))
cl_ = np.array(pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None))
d_ = np.array(pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None))
da_ = np.array(pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None))
db_ = np.array(pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None))

# %%
numCL = 70100

g_ = g_.reshape(numCL,1)
a2b_ = a2b_.reshape(numCL,1)
b2a_ = b2a_.reshape(numCL,1)
cl_ = cl_.reshape(numCL,1)
d_ = d_.reshape(numCL,1)
da_ = da_.reshape(numCL,1)
db_ = db_.reshape(numCL,1)

# %%
all_ = np.concatenate((g_, d_, da_, db_, cl_, a2b_, b2a_),axis=1)

# %%
all_
# Out:
# array([[13.03,  3.32,  1.79, ..., 10.05, 11.43, 11.65],
#        [15.9 ,  4.65,  2.53, ...,  9.  , 11.91, 12.99],
#        [13.4 ,  3.64,  1.54, ...,  8.47, 11.34, 10.53],
#        ...,
#        [ 1.73,  0.2 ,  0.11, ...,  0.4 ,  1.13,  1.  ],
#        [ 1.57,  0.22,  0.11, ...,  0.35,  0.94,  0.99],
#        [ 1.67,  0.21,  0.12, ...,  0.42,  1.08,  1.01]])

# %%
all_ = all_.reshape(7,701,100)

# %%
all_.shape
# Out:
# (7, 701, 100)

# %%
all_mean = all_.mean(axis=(0,2))

# %%
all_mean.shape
# Out:
# (701,)

# %%
g1 = g_.reshape(1,100,701)
g1 = g1.mean(axis=(0,2))
g1
# Out:
# array([2.5421398 , 1.64977175, 1.50912981, 1.50199715, 1.51480742,
#        1.53038516, 1.59447932, 1.61211127, 1.66109843, 1.62864479,
#        1.69340942, 1.70382311, 1.78319544, 1.77788873, 1.78198288,
#        1.85091298, 1.84061341, 1.77326676, 1.77756063, 1.64917261,
#        1.47126961, 1.42517832, 1.40710414, 1.39651926, 1.41228245,
#        1.38440799, 1.42248217, 1.43676177, 1.39797432, 1.43813124,
#        1.45895863, 1.42911555, 1.43713267, 1.44024251, 1.46636234,
#        1.45714693, 1.45514979, 1.47276748, 1.49009986, 1.49573466,
#        1.50134094, 1.51097004, 1.51554922, 1.53300999, 1.55061341,
#        1.55895863, 1.55647646, 1.56965763, 1.5767475 , 1.59045649,
#        1.59660485, 1.59717546, 1.62072753, 1.61633381, 1.61606277,
#        1.61415121, 1.61728959, 1.62512126, 1.6374465 , 1.63828816,
#        1.6203281 , 1.63189729, 1.64108417, 1.64801712, 1.63931526,
#        1.65594864, 1.66097004, 1.65718973, 1.66195435, 1.67522111,
# ...

# %%
d1 = d_.reshape(1,100,701)
d1 = d1.mean(axis=(0,2))
d1
# Out:
# array([0.50947218, 0.52221113, 0.51626248, 0.50737518, 0.49275321,
#        0.48522111, 0.45713267, 0.45345221, 0.46985735, 0.4235806 ,
#        0.41579173, 0.38758916, 0.39864479, 0.37372325, 0.36643367,
#        0.3489301 , 0.37840228, 0.34477889, 0.33550642, 0.34042796,
#        0.35613409, 0.35433666, 0.36141227, 0.34987161, 0.34052782,
#        0.34654779, 0.33536377, 0.38126961, 0.31854494, 0.32027104,
#        0.31299572, 0.31843081, 0.31553495, 0.31934379, 0.31232525,
#        0.30954351, 0.30647646, 0.30131241, 0.29677603, 0.29784593,
#        0.29629101, 0.28706134, 0.28540656, 0.27757489, 0.27463623,
#        0.27577746, 0.26704708, 0.26803138, 0.2667475 , 0.25885877,
#        0.25831669, 0.25402282, 0.25328103, 0.24988588, 0.24931526,
#        0.24794579, 0.24758916, 0.24439372, 0.23844508, 0.2396291 ,
#        0.23881598, 0.23778887, 0.23433666, 0.23318117, 0.23291013,
#        0.23007133, 0.22620542, 0.22586305, 0.22435093, 0.22131241,
# ...

# %%
da1 = da_.reshape(1,100,701)
da1 = da1.mean(axis=(0,2))
da1
# Out:
# array([0.21837375, 0.26055635, 0.25884451, 0.25125535, 0.24740371,
#        0.24466476, 0.23416548, 0.23149786, 0.21958631, 0.21942939,
#        0.21743224, 0.19750357, 0.2089729 , 0.18580599, 0.1925107 ,
#        0.17671897, 0.21049929, 0.18078459, 0.17610556, 0.1843224 ,
#        0.19048502, 0.18456491, 0.19172611, 0.18022825, 0.17837375,
#        0.17950071, 0.17720399, 0.17877318, 0.17042796, 0.16861626,
#        0.16577746, 0.16607703, 0.16443652, 0.16477889, 0.16253923,
#        0.15721826, 0.15372325, 0.1528388 , 0.14865906, 0.1518117 ,
#        0.15052782, 0.14523538, 0.14583452, 0.13980029, 0.1382311 ,
#        0.14091298, 0.1357632 , 0.13874465, 0.13691869, 0.13235378,
#        0.13372325, 0.13185449, 0.13171184, 0.12987161, 0.12864479,
#        0.12700428, 0.12824536, 0.12687589, 0.1235806 , 0.12319544,
#        0.12396576, 0.1232525 , 0.12256776, 0.122097  , 0.12296719,
#        0.12088445, 0.11821683, 0.11854494, 0.11796006, 0.11686163,
# ...

# %%
db1 = db_.reshape(1,100,701)
db1 = db1.mean(axis=(0,2))
db1
# Out:
# array([0.29114123, 0.26192582, 0.25736091, 0.25584879, 0.24509272,
#        0.24071327, 0.22253923, 0.2218117 , 0.25048502, 0.20407989,
#        0.19817404, 0.19022825, 0.18971469, 0.18777461, 0.17355207,
#        0.17249643, 0.167903  , 0.16386591, 0.15941512, 0.15603424,
#        0.16566334, 0.16958631, 0.16918688, 0.1696291 , 0.16269615,
#        0.16708987, 0.15820257, 0.20236805, 0.14807418, 0.15154066,
#        0.14703281, 0.15232525, 0.15091298, 0.15407989, 0.1500428 ,
#        0.15249643, 0.1528388 , 0.14834522, 0.14853067, 0.14584879,
#        0.14580599, 0.14136947, 0.13964337, 0.13793153, 0.13630528,
#        0.13510699, 0.13081312, 0.12934379, 0.12982882, 0.12651926,
#        0.12449358, 0.12253923, 0.12148359, 0.12024251, 0.12088445,
#        0.12092725, 0.11945792, 0.11766049, 0.11479315, 0.11647646,
#        0.11485021, 0.11450785, 0.11142653, 0.11059914, 0.10987161,
#        0.10928673, 0.10798859, 0.10691869, 0.10636234, 0.10453638,
# ...

# %%
cl1 = cl_.reshape(1,100,701)
cl1 = cl1.mean(axis=(0,2))
cl1
# Out:
#        0.98415121, 0.98747504, 0.99532097, 0.99640514, 0.99125535,
#        0.99992867, 1.00847361, 1.00560628, 1.00543509, 1.01340942,
# ...

# %%
g_2 = pd.DataFrame(g1)
d_2  = pd.DataFrame(d1)
da_2  = pd.DataFrame(da1)
db_2  = pd.DataFrame(db1)
cl_2  = pd.DataFrame(cl1)
a2b_2  = pd.DataFrame(a2b1)
b2a_2 = pd.DataFrame(b2a1)

# %%
g_2 = g_2.rename(columns={0 : 'g_loss'})
a2b_2 = a2b_2.rename(columns={0 : 'a2b'})
b2a_2 = b2a_2.rename(columns={0 : 'b2a'})
cl_2 = cl_2.rename(columns={0 : 'cl_loss'})
d_2 = d_2.rename(columns={0 : 'd_loss'})
da_2 = da_2.rename(columns={0 : 'da_loss'})
db_2 = db_2.rename(columns={0 : 'db_loss'})

# %%
mean_g = pd.concat([g_2, d_2, da_2, db_2, cl_2, a2b_2, b2a_2], axis=1)

# %%
# %matplotlib inline
mean_g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-d522b2d2985c> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 mean_g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g = pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None)
a2b = pd.read_csv(os.path.join(path, 'a2b.csv'), header=None)
b2a = pd.read_csv(os.path.join(path, 'b2a.csv'), header=None)
cl = pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None)
d = pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None)
da = pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None)
db = pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None)

# %%
g = g.T
a2b = a2b.T
b2a = b2a.T
cl = cl.T
d = d.T
da = da.T
db = db.T

# %%
g.head()
# Out:
#        0
# 0  13.03
# 1  15.90
# 2  13.40
# 3  12.65
# 4   8.80

# %%
g = g.rename(columns={0 : 'g_loss'})
a2b = a2b.rename(columns={0 : 'a2b'})
b2a = b2a.rename(columns={0 : 'b2a'})
cl = cl.rename(columns={0 : 'cl_loss'})
d = d.rename(columns={0 : 'd_loss'})
da = da.rename(columns={0 : 'da_loss'})
db = db.rename(columns={0 : 'db_loss'})

# %%
all = pd.concat([g, d, da, db, cl, a2b, b2a], axis=1)

# %%
all.head()
# Out:
#    g_loss  d_loss  da_loss  db_loss  cl_loss    a2b    b2a
# 0   13.03    3.32     1.79     1.53    10.05  11.43  11.65
# 1   15.90    4.65     2.53     2.12     9.00  11.91  12.99
# 2   13.40    3.64     1.54     2.11     8.47  11.34  10.53
# 3   12.65    4.21     0.85     3.35     7.58  11.87   8.36
# 4    8.80    1.53     0.67     0.86     6.73   7.74   7.79

# %%
# %matplotlib inline
all.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-54c9bd3a2d78> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 all.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-b352195a4422> in <module>
# ----> 1 g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
d.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-d8ce6191b962> in <module>
# ----> 1 d.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-51016889359b> in <module>
# ----> 1 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
a2b.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-035edc022bf8> in <module>
# ----> 1 a2b.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
b2a.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-12552202447c> in <module>
# ----> 1 b2a.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
cl.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-bd2f4e2ce3ae> in <module>
# ----> 1 cl.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
#plot.figure()
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-80230ce54591> in <module>
#       1 #plot.figure()
# ----> 2 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'
