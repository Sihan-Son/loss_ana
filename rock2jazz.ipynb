# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('rock2jazz')
path = os.getcwd()

# %%
g_ = np.array(pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None))
a2b_ = np.array(pd.read_csv(os.path.join(path, 'a2b.csv'), header=None))
b2a_ = np.array(pd.read_csv(os.path.join(path, 'b2a.csv'), header=None))
cl_ = np.array(pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None))
d_ = np.array(pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None))
da_ = np.array(pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None))
db_ = np.array(pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None))

# %%
numCL = 70100

g_ = g_.reshape(numCL,1)
a2b_ = a2b_.reshape(numCL,1)
b2a_ = b2a_.reshape(numCL,1)
cl_ = cl_.reshape(numCL,1)
d_ = d_.reshape(numCL,1)
da_ = da_.reshape(numCL,1)
db_ = db_.reshape(numCL,1)

# %%
all_ = np.concatenate((g_, d_, da_, db_, cl_, a2b_, b2a_),axis=1)

# %%
all_
# Out:
# array([[12.98,  3.27,  1.8 , ..., 10.07, 11.44, 11.61],
#        [15.64,  4.61,  2.33, ...,  8.99, 11.98, 12.65],
#        [12.68,  3.28,  1.52, ...,  8.49, 10.79, 10.38],
#        ...,
#        [ 1.46,  0.23,  0.11, ...,  0.23,  0.81,  0.88],
#        [ 1.33,  0.25,  0.12, ...,  0.21,  0.74,  0.8 ],
#        [ 1.35,  0.22,  0.1 , ...,  0.22,  0.74,  0.83]])

# %%
all_ = all_.reshape(7,701,100)

# %%
all_.shape
# Out:
# (7, 701, 100)

# %%
all_mean = all_.mean(axis=(0,2))

# %%
all_mean.shape
# Out:
# (701,)

# %%
g1 = g_.reshape(1,100,701)
g1 = g1.mean(axis=(0,2))
g1
# Out:
# array([2.62787447, 1.73152639, 1.56455064, 1.53610556, 1.59666191,
#        1.46221113, 0.92808845, 0.84586305, 0.82723252, 0.8163766 ,
#        0.82022825, 0.82942939, 0.84196862, 0.87376605, 0.88132668,
#        0.89895863, 0.92383738, 0.93329529, 0.95196862, 0.97081312,
#        0.98654779, 0.99952924, 1.01624822, 1.0303709 , 1.04365193,
#        1.06226819, 1.07399429, 1.08871612, 1.15092725, 1.03857347,
#        1.10199715, 1.1157204 , 1.13134094, 1.14212553, 1.14881598,
#        1.15843081, 1.1725535 , 1.16669044, 1.19152639, 1.19650499,
#        1.20971469, 1.20861626, 1.21359486, 1.22676177, 1.23713267,
#        1.24699001, 1.25509272, 1.24547789, 1.26951498, 1.27072753,
#        1.28360913, 1.28693295, 1.2910271 , 1.29726106, 1.29513552,
#        1.30952924, 1.3196719 , 1.3146933 , 1.32343795, 1.33392297,
#        1.33784593, 1.34125535, 1.34758916, 1.35018545, 1.35141227,
#        1.35950071, 1.36617689, 1.36457917, 1.36997147, 1.37774608,
#        1.37885877, 1.3799572 , 1.39231098, 1.39445078, 1.39657632,
#        1.39634807, 1.39686163, 1.39984308, 1.39891583, 1.40472183,
#        1.40880171, 1.40523538, 1.40801712, 1.40957204, 1.40885877,
#        1.40817404, 1.40904422, 1.40820257, 1.40589158, 1.40825963,
#        1.40485021, 1.40366619, 1.40417974, 1.39738944, 1.39590585,
#        1.39188302, 1.38907275, 1.38298146, 1.37503566, 1.36659058])

# %%
d1 = d_.reshape(1,100,701)
d1 = d1.mean(axis=(0,2))
d1
# Out:
# array([0
#        0.18997147, 0.19184023, 0.18249643, 0.18239658, 0.1821826 ,
#        0.18052782, 0.18308131, 0.17333809, 0.17631954, 0.17430813,
#        0.17142653, 0.17223966, 0.16902996, 0.16834522, 0.16332382,
#        0.16449358, 0.1739515 , 0.15463623, 0.16194009, 0.15540656,
#        0.15667618, 0.1532097 , 0.15570613, 0.15179743, 0.15165478,
#        0.1517689 , 0.14932953, 0.14780314, 0.14736091, 0.14594864,
#        0.14573466, 0.1424679 , 0.14293866, 0.14094151, 0.14281027,
#        0.13710414, 0.13955777, 0.13636234, 0.13623395, 0.13624822,
#        0.13475036, 0.13492154, 0.1317689 , 0.13263909, 0.13138374,
#        0.13031384, 0.12912981, 0.12992867, 0.12831669, 0.1271184 ,
#        0.12694722, 0.12570613, 0.12621969, 0.12472183, 0.12504993,
#        0.12420827, 0.12329529, 0.12285307, 0.12239658, 0.12243937,
#        0.12208274, 0.12189729, 0.12122682, 0.12189729, 0.12084165,
#        0.12128388, 0.12112696, 0.12192582, 0.12228245, 0.1225535 ])

# %%
cl1 = cl_.reshape(1,100,701)
cl1 = cl1.mean(axis=(0,2))
cl1
# Out:
# array([1.28510699, 1.00185449, 0.89708987, 0.86559201, 0.87801712,
#        0.78901569, 0.27736091, 0.19569187, 0.16728959, 0.14750357,
#        0.13459344, 0.13075606, 0.13098431, 0.13681883, 0.13901569,
#        0.14024251, 0.14519258, 0.14526391, 0.14721826, 0.15082739,
#        0.15398003, 0.15768902, 0.1588873 , 0.16041369, 0.16489301,
#        0.16747504, 0.16898716, 0.17425107, 0.20542083, 0.17097004,
#        0.17639087, 0.17562054, 0.17776034, 0.18105563, 0.1839087 ,
#        0.17858773, 0.18221113, 0.18771755, 0.18922967, 0.19289586,
#        0.19393723, 0.19071327, 0.19168331, 0.19172611, 0.19472183,
#        0.20115549, 0.19142653, 0.19574893, 0.19902996, 0.200699  ,
#        0.20723252, 0.20159772, 0.20058488, 0.20579173, 0.20496434,
#        0.20960057, 0.21263909, 0.20296719, 0.2075321 , 0.2111127 ,
#        0.21151213, 0.20911555, 0.20757489, 0.20883024, 0.21027104,
#        0.20824536, 0.21643367, 0.21108417, 0.2124679 , 0.21463623,
#        0.2135806 , 0.20853067, 0.21252496, 0.21587732, 0.21713267,
#        0.21557775, 0.21124108, 0.21407989, 0.21574893, 0.21380884,
#        0.21365193, 0.21389444, 0.21766049, 0.21928673, 0.2164194 ,
#        0.21656205, 0.21650499, 0.21589158, 0.21449358, 0.21696148,
#        0.21506419, 0.21398003, 0.21594864, 0.21440799, 0.21370899,
#        0.21389444, 0.21435093, 0.21352354, 0.21306705, 0.21205421])

# %%
a2b1 = a2b_.reshape(1,100,701)
a2b1 = a2b1.mean(axis=(0,2))
a2b1
# Out:
# array([1.79626248, 1.34239658, 1.22988588, 1.19681883, 1.24865906,
#        1.1274893 , 0.59547789, 0.5131669 , 0.48560628, 0.46691869,
#        0.46034237, 0.46124108, 0.46751783, 0.4814408 , 0.4888873 ,
#        0.49847361, 0.51049929, 0.51726106, 0.52754636, 0.53870185,
#        0.54589158, 0.55603424, 0.56429387, 0.57262482, 0.58125535,
#        0.58751783, 0.5964622 , 0.60680456, 0.64590585, 0.61546362,
#        0.62393723, 0.62880171, 0.63282454, 0.64131241, 0.64885877,
#        0.64686163, 0.65922967, 0.65767475, 0.67009986, 0.67168331,
#        0.68172611, 0.6774893 , 0.68156919, 0.68728959, 0.69730385,
#        0.70409415, 0.70583452, 0.69495007, 0.7156776 , 0.71566334,
#        0.72564907, 0.7264622 , 0.72610556, 0.73593438, 0.73192582,
#        0.74192582, 0.7485592 , 0.73974322, 0.74746077, 0.75589158,
#        0.7578602 , 0.75810271, 0.75589158, 0.75921541, 0.76339515,
#        0.7667475 , 0.77623395, 0.77168331, 0.77426534, 0.77533524,
#        0.7785592 , 0.77510699, 0.78188302, 0.78540656, 0.78957204,
#        0.78815977, 0.78736091, 0.78691869, 0.790699  , 0.79332382,
#        0.79422254, 0.7950214 , 0.79633381, 0.79858773, 0.79754636,
#        0.79677603, 0.79821683, 0.79733238, 0.79517832, 0.79727532,
#        0.79506419, 0.79245364, 0.79412268, 0.79011412, 0.78974322,
#        0.787903  , 0.78663338, 0.78235378, 0.77904422, 0.77504993])

# %%
b2a1 = b2a_.reshape(1,100,701)
b2a1 = b2a1.mean(axis=(0,2))
b2a1
# Out:
# array([2.11667618, 1.39085592, 1.23189729, 1.20472183, 1.22583452,
#        1.12356633, 0.60977175, 0.52817404, 0.5088873 , 0.49701854,
#        0.49456491, 0.49940086, 0.50554922, 0.52952924, 0.531398  ,
#        0.54081312, 0.55840228, 0.56094151, 0.57142653, 0.58291013,
#        0.59453638, 0.60081312, 0.61049929, 0.6182311 , 0.62718973,
#        0.64231098, 0.64649073, 0.65623395, 0.71062767, 0.59416548,
#        0.65472183, 0.6625535 , 0.67661912, 0.68196862, 0.68366619,
#        0.69049929, 0.69540656, 0.69664765, 0.71078459, 0.7174465 ,
#        0.72231098, 0.72185449, 0.72373752, 0.73094151, 0.7346505 ,
#        0.74398003, 0.74022825, 0.74639087, 0.75296719, 0.75564907,
#        0.76524964, 0.76184023, 0.76516405, 0.76697575, 0.76828816,
#        0.77694722, 0.78379458, 0.77787447, 0.78365193, 0.78908702,
#        0.79145506, 0.79201141, 0.79920114, 0.79942939, 0.79844508,
#        0.80126961, 0.80630528, 0.80383738, 0.80820257, 0.81718973,
#        0.8135806 , 0.81339515, 0.82266762, 0.82517832, 0.82405136,
#        0.82369472, 0.82081312, 0.82671897, 0.82416548, 0.82536377,
#        0.82834522, 0.82430813, 0.82972896, 0.83072753, 0.82757489,
#        0.82763195, 0.82794579, 0.82710414, 0.82549215, 0.82828816,
#        0.8246933 , 0.82519258, 0.82633381, 0.82126961, 0.82014265,
#        0.81757489, 0.8167475 , 0.81435093, 0.80907275, 0.80313837])

# %%
g_2 = pd.DataFrame(g1)
d_2  = pd.DataFrame(d1)
da_2  = pd.DataFrame(da1)
db_2  = pd.DataFrame(db1)
cl_2  = pd.DataFrame(cl1)
a2b_2  = pd.DataFrame(a2b1)
b2a_2 = pd.DataFrame(b2a1)

# %%
g_2 = g_2.rename(columns={0 : 'g_loss'})
a2b_2 = a2b_2.rename(columns={0 : 'a2b'})
b2a_2 = b2a_2.rename(columns={0 : 'b2a'})
cl_2 = cl_2.rename(columns={0 : 'cl_loss'})
d_2 = d_2.rename(columns={0 : 'd_loss'})
da_2 = da_2.rename(columns={0 : 'da_loss'})
db_2 = db_2.rename(columns={0 : 'db_loss'})

# %%
mean_g = pd.concat([g_2, d_2, da_2, db_2, cl_2, a2b_2, b2a_2], axis=1)

# %%
# %matplotlib inline
mean_g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d522b2d2985c> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 mean_g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g = pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None)
a2b = pd.read_csv(os.path.join(path, 'a2b.csv'), header=None)
b2a = pd.read_csv(os.path.join(path, 'b2a.csv'), header=None)
cl = pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None)
d = pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None)
da = pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None)
db = pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None)

# %%
g = g.T
a2b = a2b.T
b2a = b2a.T
cl = cl.T
d = d.T
da = da.T
db = db.T

# %%
g.head()
# Out:
#        0
# 0  12.98
# 1  15.64
# 2  12.68
# 3  13.30
# 4   8.93

# %%
g = g.rename(columns={0 : 'g_loss'})
a2b = a2b.rename(columns={0 : 'a2b'})
b2a = b2a.rename(columns={0 : 'b2a'})
cl = cl.rename(columns={0 : 'cl_loss'})
d = d.rename(columns={0 : 'd_loss'})
da = da.rename(columns={0 : 'da_loss'})
db = db.rename(columns={0 : 'db_loss'})

# %%
all = pd.concat([g, d, da, db, cl, a2b, b2a], axis=1)

# %%
all.head()
# Out:
#    g_loss  d_loss  da_loss  db_loss  cl_loss    a2b    b2a
# 0   12.98    3.27     1.80     1.47    10.07  11.44  11.61
# 1   15.64    4.61     2.33     2.28     8.99  11.98  12.65
# 2   12.68    3.28     1.52     1.77     8.49  10.79  10.38
# 3   13.30    4.60     1.05     3.55     7.60  12.21   8.69
# 4    8.93    1.66     0.80     0.86     6.81   7.84   7.90

# %%
# %matplotlib inline
all.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-54c9bd3a2d78> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 all.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-b352195a4422> in <module>
# ----> 1 g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
d.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d8ce6191b962> in <module>
# ----> 1 d.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-51016889359b> in <module>
# ----> 1 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
a2b.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-035edc022bf8> in <module>
# ----> 1 a2b.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
b2a.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-12552202447c> in <module>
# ----> 1 b2a.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
cl.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-bd2f4e2ce3ae> in <module>
# ----> 1 cl.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
#plot.figure()
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-80230ce54591> in <module>
#       1 #plot.figure()
# ----> 2 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'
