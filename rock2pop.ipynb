# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('rock2pop')
path = os.getcwd()

# %%
g_ = np.array(pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None))
a2b_ = np.array(pd.read_csv(os.path.join(path, 'a2b.csv'), header=None))
b2a_ = np.array(pd.read_csv(os.path.join(path, 'b2a.csv'), header=None))
cl_ = np.array(pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None))
d_ = np.array(pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None))
da_ = np.array(pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None))
db_ = np.array(pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None))

# %%
numCL = 91200

g_ = g_.reshape(numCL,1)
a2b_ = a2b_.reshape(numCL,1)
b2a_ = b2a_.reshape(numCL,1)
cl_ = cl_.reshape(numCL,1)
d_ = d_.reshape(numCL,1)
da_ = da_.reshape(numCL,1)
db_ = db_.reshape(numCL,1)

# %%
all_ = np.concatenate((g_, d_, da_, db_, cl_, a2b_, b2a_),axis=1)

# %%
all_
# Out:
# array([[13.01,  3.22,  1.7 , ..., 10.07, 11.47, 11.61],
#        [16.2 ,  4.91,  2.39, ...,  8.94, 12.41, 12.72],
#        [12.91,  3.5 ,  1.64, ...,  8.5 , 10.81, 10.6 ],
#        ...,
#        [ 2.99,  0.06,  0.  , ...,  1.12,  1.99,  2.12],
#        [ 2.98,  0.04,  0.  , ...,  1.13,  1.98,  2.13],
#        [ 2.86,  0.05,  0.  , ...,  1.04,  1.86,  2.04]])

# %%
all_ = all_.reshape(7,912,100)

# %%
all_.shape
# Out:
# (7, 912, 100)

# %%
all_mean = all_.mean(axis=(0,2))

# %%
all_mean.shape
# Out:
# (912,)

# %%
g1 = g_.reshape(1,100,912)
g1 = g1.mean(axis=(0,2))
g1
# Out:
# array([2.40388158, 1.96953947, 1.93360746, 1.93088816, 1.97507675,
#        2.0316557 , 2.46066886, 2.48780702, 2.5029386 , 2.48940789,
#        2.52957237, 2.51756579, 2.52539474, 2.53099781, 2.52453947,
#        2.56280702, 2.57037281, 2.5635307 , 2.5589693 , 2.55917763,
#        2.91025219, 3.05599781, 3.05935307, 2.61208333, 2.55174342,
#        2.57713816, 2.62014254, 2.61985746, 2.63111842, 2.63183114,
#        2.61294956, 2.59184211, 2.61902412, 2.62508772, 2.61695175,
#        2.80301535, 2.93441886, 2.61423246, 2.64544956, 2.60528509,
#        2.6208443 , 2.68993421, 2.62389254, 2.62631579, 2.65394737,
#        2.67654605, 2.59091009, 2.89080044, 2.59389254, 2.89182018,
#        2.63385965, 2.7876864 , 2.66435307, 2.76025219, 2.65453947,
#        2.70732456, 2.6995614 , 2.74196272, 3.04372807, 3.06389254,
#        3.06617325, 3.06587719, 2.7858443 , 2.71320175, 2.89767544,
#        2.74722588, 2.97382675, 2.82971491, 2.92275219, 3.05323465,
#        3.06401316, 3.05705044, 2.94357456, 2.62484649, 2.78207237,
#        2.9714364 , 2.97890351, 2.8129386 , 2.90961623, 2.99232456,
#        2.72561404, 2.78815789, 3.04201754, 3.06360746, 3.06580044,
#        3.06740132, 2.57610746, 2.74294956, 2.67266447, 2.67985746,
#        2.69429825, 2.72046053, 3.03245614, 3.03188596, 2.89027412,
#        2.73058114, 2.76379386, 2.71445175, 2.65323465, 2.84506579])

# %%
d1 = d_.reshape(1,100,912)
d1 = d1.mean(axis=(0,2))
d1
# Out:
# array([0.54461623, 0.4816557 , 0.4701864 , 0.44992325, 0.43684211,
#        0.41132675, 0.2466557 , 0.22219298, 0.21791667, 0.22092105,
#        0.21654605, 0.19824561, 0.20614035, 0.21300439, 0.19588816,
#        0.2033443 , 0.18515351, 0.18932018, 0.18816886, 0.17871711,
#        0.06707237, 0.01013158, 0.00828947, 0.19244518, 0.18258772,
#        0.16865132, 0.15714912, 0.15891447, 0.15651316, 0.16566886,
#        0.16686404, 0.16107456, 0.15384868, 0.15985746, 0.1522807 ,
#        0.10194079, 0.0558114 , 0.15697368, 0.15044956, 0.15473684,
#        0.14779605, 0.13933114, 0.15358553, 0.14662281, 0.14322368,
#        0.13179825, 0.15871711, 0.07735746, 0.14660088, 0.0725    ,
#        0.13487939, 0.09616228, 0.13837719, 0.10942982, 0.12463816,
#        0.12506579, 0.12935307, 0.09875   , 0.02053728, 0.00944079,
#        0.00427632, 0.00230263, 0.09239035, 0.10175439, 0.05878289,
#        0.09292763, 0.03718202, 0.07239035, 0.0495614 , 0.01450658,
#        0.00800439, 0.00777412, 0.03758772, 0.12710526, 0.08441886,
#        0.030625  , 0.02984649, 0.07471491, 0.05182018, 0.02442982,
#        0.09321272, 0.083125  , 0.01621711, 0.01007675, 0.00679825,
#        0.00218202, 0.13803728, 0.09246711, 0.11537281, 0.10252193,
#        0.10577851, 0.10351974, 0.02222588, 0.01473684, 0.04308114,
#        0.08705044, 0.07951754, 0.09569079, 0.11326754, 0.07576754])

# %%
da1 = da_.reshape(1,100,912)
da1 = da1.mean(axis=(0,2))
da1
# Out:
# array([2.75131579e-01, 2.45734649e-01, 2.40482456e-01, 2.22949561e-01,
#        2.18070175e-01, 2.17675439e-01, 3.65021930e-02, 6.22807018e-03,
#        5.72368421e-03, 6.10745614e-03, 4.70394737e-03, 3.96929825e-03,
#        3.38815789e-03, 2.93859649e-03, 2.83991228e-03, 2.19298246e-03,
#        2.08333333e-03, 1.63377193e-03, 1.51315789e-03, 1.35964912e-03,
#        1.49122807e-03, 1.21710526e-03, 1.08552632e-03, 3.38815789e-03,
#        5.92105263e-04, 7.89473684e-04, 6.90789474e-04, 5.81140351e-04,
#        5.04385965e-04, 4.82456140e-04, 5.70175439e-04, 3.17982456e-04,
#        6.03070175e-04, 3.39912281e-04, 1.20614035e-04, 4.38596491e-04,
#        1.97368421e-04, 2.41228070e-04, 1.64473684e-04, 2.96052632e-04,
#        4.38596491e-05, 1.20614035e-04, 1.42543860e-04, 1.86403509e-04,
#        1.53508772e-04, 6.57894737e-05, 1.20614035e-04, 7.67543860e-05,
#        4.38596491e-05, 1.42543860e-04, 9.86842105e-05, 8.77192982e-05,
#        8.77192982e-05, 2.19298246e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.48245614e-05, 2.19298246e-05, 5.48245614e-05,
#        1.09649123e-05, 6.57894737e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.28947368e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
db1 = db_.reshape(1,100,912)
db1 = db1.mean(axis=(0,2))
db1
# Out:
# array([0.26945175, 0.23563596, 0.22984649, 0.22716009, 0.2183443 ,
#        0.19383772, 0.21080044, 0.21631579, 0.21155702, 0.21408991,
#        0.21038377, 0.19289474, 0.20120614, 0.20881579, 0.19172149,
#        0.19974781, 0.1816886 , 0.18628289, 0.18527412, 0.1758443 ,
#        0.06476974, 0.0079057 , 0.00361842, 0.18809211, 0.18095395,
#        0.16677632, 0.15530702, 0.15741228, 0.15506579, 0.16440789,
#        0.16519737, 0.16      , 0.15251096, 0.15876096, 0.15131579,
#        0.10073465, 0.05523026, 0.15621711, 0.14942982, 0.15392544,
#        0.14699561, 0.1383443 , 0.15287281, 0.14598684, 0.14256579,
#        0.13105263, 0.15808114, 0.07660088, 0.14609649, 0.07186404,
#        0.13439693, 0.09549342, 0.13794956, 0.10888158, 0.12413377,
#        0.12453947, 0.1289364 , 0.09836623, 0.02017544, 0.00883772,
#        0.00304825, 0.00183114, 0.09202851, 0.10148026, 0.0583443 ,
#        0.09258772, 0.03690789, 0.0720614 , 0.04934211, 0.01439693,
#        0.0070614 , 0.00732456, 0.03717105, 0.12692982, 0.08417763,
#        0.03037281, 0.02966009, 0.0745943 , 0.05164474, 0.02424342,
#        0.09305921, 0.08294956, 0.01612939, 0.00998904, 0.00632675,
#        0.00190789, 0.1379386 , 0.09236842, 0.11525219, 0.10237939,
#        0.10570175, 0.10337719, 0.02216009, 0.01469298, 0.04303728,
#        0.08698465, 0.07938596, 0.09553728, 0.11321272, 0.07570175])

# %%
cl1 = cl_.reshape(1,100,912)
cl1 = cl1.mean(axis=(0,2))
cl1
# Out:
# array([1.23778509, 1.10565789, 1.10189693, 1.09205044, 1.09178728,
#        1.10247807, 1.08741228, 1.07144737, 1.0748136 , 1.0726864 ,
#        1.07278509, 1.07176535, 1.07258772, 1.0727193 , 1.07163377,
#        1.07391447, 1.07326754, 1.07296053, 1.0725    , 1.07041667,
#        1.07252193, 1.07337719, 1.07212719, 1.07283991, 1.07278509,
#        1.07286184, 1.07225877, 1.07241228, 1.07245614, 1.07344298,
#        1.07072368, 1.07263158, 1.07327851, 1.07400219, 1.07031798,
#        1.07080044, 1.07230263, 1.07277412, 1.07286184, 1.07310307,
#        1.07246711, 1.07214912, 1.07235746, 1.07368421, 1.07264254,
#        1.07255482, 1.0720614 , 1.07259868, 1.07270833, 1.07212719,
#        1.07179825, 1.07142544, 1.07219298, 1.07114035, 1.07108553,
#        1.07095395, 1.07191886, 1.07014254, 1.07323465, 1.07320175,
#        1.07262061, 1.0720943 , 1.07355263, 1.07225877, 1.07137061,
#        1.07076754, 1.07105263, 1.07297149, 1.07183114, 1.07074561,
#        1.07212719, 1.0722807 , 1.07367325, 1.07233553, 1.07307018,
#        1.07210526, 1.07270833, 1.0729386 , 1.07190789, 1.07222588,
#        1.07161184, 1.0720943 , 1.07195175, 1.07298246, 1.07311404,
#        1.07376096, 1.07072368, 1.07216009, 1.07292763, 1.073125  ,
#        1.07373904, 1.07257675, 1.07151316, 1.07161184, 1.07324561,
#        1.07308114, 1.07307018, 1.07359649, 1.07287281, 1.0739364 ])

# %%
a2b1 = a2b_.reshape(1,100,912)
a2b1 = a2b1.mean(axis=(0,2))
a2b1
# Out:
# array([1.79399123, 1.58961623, 1.5285307 , 1.5054057 , 1.54516447,
#        1.59939693, 1.5458114 , 1.50528509, 1.51266447, 1.49782895,
#        1.53707237, 1.52360746, 1.53122807, 1.53653509, 1.52975877,
#        1.56789474, 1.57580044, 1.56847588, 1.56395833, 1.56398026,
#        1.91505482, 2.06076754, 2.06355263, 1.61808114, 1.55589912,
#        1.58085526, 1.62383772, 1.62337719, 1.63444079, 1.635     ,
#        1.61538377, 1.59438596, 1.62160088, 1.6276864 , 1.61917763,
#        1.80517544, 1.93631579, 1.61651316, 1.6472807 , 1.60718202,
#        1.62236842, 1.69160088, 1.62551535, 1.62779605, 1.65535088,
#        1.67791667, 1.59201754, 1.8920614 , 1.59516447, 1.89309211,
#        1.63496711, 1.78908991, 1.66548246, 1.76110746, 1.65569079,
#        1.70826754, 1.70044956, 1.74292763, 2.04469298, 2.06468202,
#        2.06703947, 2.06698465, 1.78656798, 1.71422149, 1.89850877,
#        1.7477193 , 1.97451754, 1.83054825, 1.92346491, 2.05406798,
#        2.06457237, 2.05747807, 1.94422149, 1.62564693, 1.78285088,
#        1.97205044, 1.97957237, 1.81341009, 1.91027412, 1.99288377,
#        1.72611842, 1.7885636 , 2.04256579, 2.06428728, 2.06621711,
#        2.06798246, 1.57663377, 1.74346491, 1.67310307, 1.68024123,
#        1.69479167, 1.72092105, 2.03283991, 2.03235746, 1.89065789,
#        1.73093202, 1.76423246, 1.71470395, 1.65358553, 1.84544956])

# %%
b2a1 = b2a_.reshape(1,100,912)
b2a1 = b2a1.mean(axis=(0,2))
b2a1
# Out:
# array([1.84745614, 1.48555921, 1.50714912, 1.51755482, 1.52194079,
#        1.53448465, 2.00219298, 2.05389254, 2.06493421, 2.06419956,
#        2.06529605, 2.06530702, 2.06680921, 2.06699561, 2.06618421,
#        2.06866228, 2.06797149, 2.06803728, 2.06775219, 2.06593202,
#        2.06746711, 2.06883772, 2.06802632, 2.06689693, 2.06859649,
#        2.06906798, 2.06871711, 2.06910088, 2.06921053, 2.07028509,
#        2.0676864 , 2.07002193, 2.07065789, 2.07139254, 2.06811404,
#        2.06870614, 2.07041667, 2.07061404, 2.07094298, 2.07125   ,
#        2.07089912, 2.07041667, 2.07070175, 2.07221491, 2.0708114 ,
#        2.07107456, 2.07052632, 2.07130482, 2.07139254, 2.07082237,
#        2.07051535, 2.07006579, 2.07093202, 2.07024123, 2.06998904,
#        2.06980263, 2.07085526, 2.06932018, 2.07232456, 2.07233553,
#        2.07171053, 2.07111842, 2.0726864 , 2.07137061, 2.07072368,
#        2.06976974, 2.07012061, 2.0720614 , 2.07135965, 2.06983553,
#        2.07139254, 2.07152412, 2.07321272, 2.07175439, 2.07245614,
#        2.07137061, 2.07194079, 2.07237939, 2.07133772, 2.07185307,
#        2.07101974, 2.07157895, 2.07152412, 2.07237939, 2.07260965,
#        2.07310307, 2.07033991, 2.0716886 , 2.07251096, 2.07262061,
#        2.07323465, 2.07222588, 2.07097588, 2.07120614, 2.07276316,
#        2.0726864 , 2.07276316, 2.07321272, 2.07243421, 2.07359649])

# %%
g_2 = pd.DataFrame(g1)
d_2  = pd.DataFrame(d1)
da_2  = pd.DataFrame(da1)
db_2  = pd.DataFrame(db1)
cl_2  = pd.DataFrame(cl1)
a2b_2  = pd.DataFrame(a2b1)
b2a_2 = pd.DataFrame(b2a1)

# %%
g_2 = g_2.rename(columns={0 : 'g_loss'})
a2b_2 = a2b_2.rename(columns={0 : 'a2b'})
b2a_2 = b2a_2.rename(columns={0 : 'b2a'})
cl_2 = cl_2.rename(columns={0 : 'cl_loss'})
d_2 = d_2.rename(columns={0 : 'd_loss'})
da_2 = da_2.rename(columns={0 : 'da_loss'})
db_2 = db_2.rename(columns={0 : 'db_loss'})

# %%
mean_g = pd.concat([g_2, d_2, da_2, db_2, cl_2, a2b_2, b2a_2], axis=1)

# %%
# %matplotlib inline
mean_g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d522b2d2985c> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 mean_g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g = pd.read_csv(os.path.join(path, 'g_loss.csv'), header=None)
a2b = pd.read_csv(os.path.join(path, 'a2b.csv'), header=None)
b2a = pd.read_csv(os.path.join(path, 'b2a.csv'), header=None)
cl = pd.read_csv(os.path.join(path, 'cl_loss.csv'), header=None)
d = pd.read_csv(os.path.join(path, 'd_loss.csv'), header=None)
da = pd.read_csv(os.path.join(path, 'da_loss.csv'), header=None)
db = pd.read_csv(os.path.join(path, 'db_loss.csv'), header=None)

# %%
g = g.T
a2b = a2b.T
b2a = b2a.T
cl = cl.T
d = d.T
da = da.T
db = db.T

# %%
g.head()
# Out:
#        0
# 0  13.01
# 1  16.20
# 2  12.91
# 3  12.60
# 4   8.63

# %%
g = g.rename(columns={0 : 'g_loss'})
a2b = a2b.rename(columns={0 : 'a2b'})
b2a = b2a.rename(columns={0 : 'b2a'})
cl = cl.rename(columns={0 : 'cl_loss'})
d = d.rename(columns={0 : 'd_loss'})
da = da.rename(columns={0 : 'da_loss'})
db = db.rename(columns={0 : 'db_loss'})

# %%
all = pd.concat([g, d, da, db, cl, a2b, b2a], axis=1)

# %%
all.head()
# Out:
#    g_loss  d_loss  da_loss  db_loss  cl_loss    a2b    b2a
# 0   13.01    3.22     1.70     1.52    10.07  11.47  11.61
# 1   16.20    4.91     2.39     2.52     8.94  12.41  12.72
# 2   12.91    3.50     1.64     1.86     8.50  10.81  10.60
# 3   12.60    4.07     1.06     3.01     7.75  11.48   8.87
# 4    8.63    1.51     0.69     0.82     6.83   7.77   7.68

# %%
# %matplotlib inline
all.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-54c9bd3a2d78> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 all.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
g.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-b352195a4422> in <module>
# ----> 1 g.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
d.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-d8ce6191b962> in <module>
# ----> 1 d.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-51016889359b> in <module>
# ----> 1 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
a2b.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-035edc022bf8> in <module>
# ----> 1 a2b.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
b2a.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-12552202447c> in <module>
# ----> 1 b2a.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
cl.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-bd2f4e2ce3ae> in <module>
# ----> 1 cl.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
da.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ca0a94f8432f> in <module>
# ----> 1 da.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'

# %%
#plot.figure()
db.plot(figsize=(15, 7)).line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-80230ce54591> in <module>
#       1 #plot.figure()
# ----> 2 db.plot(figsize=(15, 7)).line()
#
# AttributeError: 'AxesSubplot' object has no attribute 'line'
